# %% [markdown]
# <a href="https://colab.research.google.com/github/ethlynsaltzman/project-3/blob/main/SaltzmanPythoncapstoneproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#in this analysis I decided to look the relationship between SWD status and graduation rate"
#Q1: Have graduation rates have changed for students with and without disabilities.
#Q2: Has the gap between graduation rates of students with and without disabilities increased

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


grad = pd.read_csv('/content/2017_-_2018_Graduation_Outcomes_School_20240102.csv')
pd.options.display.max_rows = 200
grad.head(100)
# Out:
# <ipython-input-194-3420bc711cad>:11: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   grad = pd.read_csv('/content/2017_-_2018_Graduation_Outcomes_School_20240102.csv')
#        DBN                 School Name Demographic Category  \
# 0   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 1   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 2   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 3   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 4   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 5   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 6   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 7   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 8   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 9   01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 10  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 11  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 12  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 13  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 14  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 15  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 16  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 17  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 18  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 19  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 20  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 21  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 22  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 23  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 24  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 25  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 26  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 27  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 28  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 29  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 30  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 31  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 32  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 33  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 34  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 35  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 36  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 37  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 38  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 39  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 40  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 41  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 42  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 43  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 44  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 45  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 46  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 47  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 48  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 49  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 50  01M292  ORCHARD COLLEGIATE ACADEMY         All Students
# 51  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 52  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 53  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 54  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 55  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 56  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 57  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 58  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 59  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 60  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 61  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 62  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 63  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 64  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 65  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 66  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 67  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 68  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 69  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 70  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 71  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 72  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 73  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 74  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 75  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 76  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 77  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 78  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 79  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 80  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 81  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 82  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 83  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 84  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 85  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 86  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 87  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 88  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 89  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 90  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 91  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 92  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 93  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 94  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 95  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 96  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 97  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 98  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
# 99  01M292  ORCHARD COLLEGIATE ACADEMY           ELL Status
#
#    Demographic Variable Cohort Year         Cohort Total Cohort #  \
# 0          All Students       2,014  4 year August             29
# 1          All Students       2,013  4 year August             36
# 2          All Students       2,012  4 year August             44
# 3          All Students       2,011  4 year August             73
# 4          All Students       2,010  4 year August             61
# 5          All Students       2,009  4 year August             85
# 6          All Students       2,008  4 year August             70
# 7          All Students       2,007  4 year August             77
# 8          All Students       2,006  4 year August             78
# 9          All Students       2,005  4 year August             64
# 10         All Students       2,014    4 year June             29
# 11         All Students       2,013    4 year June             36
# 12         All Students       2,012    4 year June             44
# 13         All Students       2,011    4 year June             73
# 14         All Students       2,010    4 year June             61
# 15         All Students       2,009    4 year June             85
# 16         All Students       2,008    4 year June             70
# 17         All Students       2,007    4 year June             77
# 18         All Students       2,006    4 year June             78
# 19         All Students       2,005    4 year June             64
# 20         All Students       2,004    4 year June             55
# 21         All Students       2,003    4 year June              5
# 22         All Students       2,013  5 year August             36
# 23         All Students       2,012  5 year August             41
# 24         All Students       2,011  5 year August             68
# 25         All Students       2,010  5 year August             55
# 26         All Students       2,009  5 year August             82
# 27         All Students       2,008  5 year August             68
# 28         All Students       2,007  5 year August             77
# 29         All Students       2,006  5 year August             71
# 30         All Students       2,013    5 year June             36
# 31         All Students       2,012    5 year June             41
# 32         All Students       2,011    5 year June             68
# 33         All Students       2,010    5 year June             55
# 34         All Students       2,009    5 year June             82
# 35         All Students       2,008    5 year June             68
# 36         All Students       2,007    5 year June             77
# 37         All Students       2,006    5 year June             71
# 38         All Students       2,005    5 year June             66
# 39         All Students       2,004    5 year June             58
# 40         All Students       2,003    5 year June              5
# 41         All Students       2,012    6 year June             41
# 42         All Students       2,011    6 year June             68
# 43         All Students       2,010    6 year June             54
# 44         All Students       2,009    6 year June             82
# 45         All Students       2,008    6 year June             68
# 46         All Students       2,007    6 year June             77
# 47         All Students       2,006    6 year June             73
# 48         All Students       2,005    6 year June             65
# 49         All Students       2,004    6 year June             56
# 50         All Students       2,003    6 year June              5
# 51          Current ELL       2,014  4 year August              1
# 52          Current ELL       2,013  4 year August              2
# 53          Current ELL       2,012  4 year August              6
# 54          Current ELL       2,011  4 year August             14
# 55          Current ELL       2,014    4 year June              1
# 56          Current ELL       2,013    4 year June              2
# 57          Current ELL       2,012    4 year June              6
# 58          Current ELL       2,011    4 year June             14
# 59          Current ELL       2,013  5 year August              2
# 60          Current ELL       2,012  5 year August              4
# 61          Current ELL       2,013    5 year June              2
# 62          Current ELL       2,012    5 year June              4
# 63          Current ELL       2,012    6 year June              4
# 64          Current ELL       2,011    6 year June             13
# 65                  ELL       2,014  4 year August              1
# 66                  ELL       2,013  4 year August              2
# 67                  ELL       2,012  4 year August              6
# 68                  ELL       2,011  4 year August             14
# 69                  ELL       2,010  4 year August             14
# 70                  ELL       2,009  4 year August             16
# 71                  ELL       2,008  4 year August             19
# 72                  ELL       2,007  4 year August              9
# 73                  ELL       2,006  4 year August              5
# 74                  ELL       2,005  4 year August              5
# 75                  ELL       2,014    4 year June              1
# 76                  ELL       2,013    4 year June              2
# 77                  ELL       2,012    4 year June              6
# 78                  ELL       2,011    4 year June             14
# 79                  ELL       2,010    4 year June             14
# 80                  ELL       2,009    4 year June             16
# 81                  ELL       2,008    4 year June             19
# 82                  ELL       2,007    4 year June              9
# 83                  ELL       2,006    4 year June              5
# 84                  ELL       2,005    4 year June              5
# 85                  ELL       2,004    4 year June              6
# 86                  ELL       2,003    4 year June              2
# 87                  ELL       2,013  5 year August              2
# 88                  ELL       2,012  5 year August              4
# 89                  ELL       2,011  5 year August             13
# 90                  ELL       2,010  5 year August             12
# 91                  ELL       2,009  5 year August             15
# 92                  ELL       2,008  5 year August             18
# 93                  ELL       2,007  5 year August              9
# 94                  ELL       2,006  5 year August              6
# 95                  ELL       2,013    5 year June              2
# 96                  ELL       2,012    5 year June              4
# 97                  ELL       2,011    5 year June             13
# 98                  ELL       2,010    5 year June             12
# 99                  ELL       2,009    5 year June             15
#
#    Total Grads # Total Grads % of cohort Total Regents #  ...  \
# 0             28                    96.6              25  ...
# 1             25                    69.4              23  ...
# 2             24                    54.5              20  ...
# 3             46                    63.0              41  ...
# 4             26                    42.6              26  ...
# 5             49                    57.6              44  ...
# 6             36                    51.4              30  ...
# 7             45                    58.4              29  ...
# 8             44                    56.4              37  ...
# 9             44                    68.8              27  ...
# 10            25                    86.2              22  ...
# 11            24                    66.7              23  ...
# 12            23                    52.3              19  ...
# 13            46                    63.0              41  ...
# 14            24                    39.3              24  ...
# 15            47                    55.3              42  ...
# 16            35                    50.0              29  ...
# 17            41                    53.2              28  ...
# 18            43                    55.1              36  ...
# 19            43                    67.2              27  ...
# 20            37                    67.3              17  ...
# 21             0                     0.0               0  ...
# 22            27                    75.0              23  ...
# 23            28                    68.3              22  ...
# 24            48                    70.6              42  ...
# 25            28                    50.9              27  ...
# 26            57                    69.5              50  ...
# 27            40                    58.8              34  ...
# 28            51                    66.2              30  ...
# 29            44                    62.0              36  ...
# 30            27                    75.0              23  ...
# 31            28                    68.3              22  ...
# 32            48                    70.6              42  ...
# 33            28                    50.9              27  ...
# 34            55                    67.1              49  ...
# 35            39                    57.4              33  ...
# 36            51                    66.2              30  ...
# 37            44                    62.0              36  ...
# 38            46                    69.7              28  ...
# 39            39                    67.2              18  ...
# 40             3                    60.0               0  ...
# 41            28                    68.3              22  ...
# 42            49                    72.1              42  ...
# 43            30                    55.6              28  ...
# 44            61                    74.4              53  ...
# 45            40                    58.8              34  ...
# 46            53                    68.8              31  ...
# 47            44                    60.3              36  ...
# 48            47                    72.3              29  ...
# 49            41                    73.2              18  ...
# 50             3                    60.0               0  ...
# 51             s                       s               s  ...
# 52             s                       s               s  ...
# 53             2                    33.3               1  ...
# 54             3                    21.4               1  ...
# 55             s                       s               s  ...
# 56             s                       s               s  ...
# 57             2                    33.3               1  ...
# 58             3                    21.4               1  ...
# 59             s                       s               s  ...
# 60             s                       s               s  ...
# 61             s                       s               s  ...
# 62             s                       s               s  ...
# 63             s                       s               s  ...
# 64             5                    38.5               2  ...
# 65             s                       s               s  ...
# 66             s                       s               s  ...
# 67             s                       s               s  ...
# 68             3                    21.4               1  ...
# 69             s                       s               s  ...
# 70             s                       s               s  ...
# 71             s                       s               s  ...
# 72             s                       s               s  ...
# 73             s                       s               s  ...
# 74             s                       s               s  ...
# 75             s                       s               s  ...
# 76             s                       s               s  ...
# 77             s                       s               s  ...
# 78             3                    21.4               1  ...
# 79             s                       s               s  ...
# 80             s                       s               s  ...
# 81             s                       s               s  ...
# 82             s                       s               s  ...
# 83             s                       s               s  ...
# 84             s                       s               s  ...
# 85             3                    50.0               0  ...
# 86             s                       s               s  ...
# 87             s                       s               s  ...
# 88             s                       s               s  ...
# 89             4                    30.8               2  ...
# 90             s                       s               s  ...
# 91             6                    40.0               5  ...
# 92             s                       s               s  ...
# 93             s                       s               s  ...
# 94             s                       s               s  ...
# 95             s                       s               s  ...
# 96             s                       s               s  ...
# 97             4                    30.8               2  ...
# 98             s                       s               s  ...
# 99             5                    33.3               5  ...
#
#    Regents w/o Advanced # Regents w/o Advanced % of cohort  \
# 0                      25                             86.2
# 1                      23                             63.9
# 2                      19                             43.2
# 3                      41                             56.2
# 4                      25                             41.0
# 5                      44                             51.8
# 6                      30                             42.9
# 7                      29                             37.7
# 8                      37                             47.4
# 9                      27                             42.2
# 10                     22                             75.9
# 11                     23                             63.9
# 12                     18                             40.9
# 13                     41                             56.2
# 14                     23                             37.7
# 15                     42                             49.4
# 16                     29                             41.4
# 17                     28                             36.4
# 18                     36                             46.2
# 19                     27                             42.2
# 20                     17                             30.9
# 21                      0                              0.0
# 22                     23                             63.9
# 23                     21                             51.2
# 24                     42                             61.8
# 25                     26                             47.3
# 26                     50                             61.0
# 27                     34                             50.0
# 28                     30                             39.0
# 29                     36                             50.7
# 30                     23                             63.9
# 31                     21                             51.2
# 32                     42                             61.8
# 33                     26                             47.3
# 34                     49                             59.8
# 35                     33                             48.5
# 36                     30                             39.0
# 37                     36                             50.7
# 38                     28                             42.4
# 39                     18                             31.0
# 40                      0                              0.0
# 41                     21                             51.2
# 42                     42                             61.8
# 43                     27                             50.0
# 44                     53                             64.6
# 45                     34                             50.0
# 46                     31                             40.3
# 47                     36                             49.3
# 48                     29                             44.6
# 49                     18                             32.1
# 50                      0                              0.0
# 51                      s                                s
# 52                      s                                s
# 53                      1                             16.7
# 54                      1                              7.1
# 55                      s                                s
# 56                      s                                s
# 57                      1                             16.7
# 58                      1                              7.1
# 59                      s                                s
# 60                      s                                s
# 61                      s                                s
# 62                      s                                s
# 63                      s                                s
# 64                      2                             15.4
# 65                      s                                s
# 66                      s                                s
# 67                      s                                s
# 68                      1                              7.1
# 69                      s                                s
# 70                      s                                s
# 71                      s                                s
# 72                      s                                s
# 73                      s                                s
# 74                      s                                s
# 75                      s                                s
# 76                      s                                s
# 77                      s                                s
# 78                      1                              7.1
# 79                      s                                s
# 80                      s                                s
# 81                      s                                s
# 82                      s                                s
# 83                      s                                s
# 84                      s                                s
# 85                      0                              0.0
# 86                      s                                s
# 87                      s                                s
# 88                      s                                s
# 89                      2                             15.4
# 90                      s                                s
# 91                      5                             33.3
# 92                      s                                s
# 93                      s                                s
# 94                      s                                s
# 95                      s                                s
# 96                      s                                s
# 97                      2                             15.4
# 98                      s                                s
# 99                      5                             33.3
#
#    Regents w/o Advanced % of grads Local # Local % of cohort Local % of grads  \
# 0                             89.3       3              10.3             10.7
# 1                             92.0       2               5.6              8.0
# 2                             79.2       4               9.1             16.7
# 3                             89.1       5               6.8             10.9
# 4                             96.2       0               0.0              0.0
# 5                             89.8       5               5.9             10.2
# 6                             83.3       6               8.6             16.7
# 7                             64.4      16              20.8             35.6
# 8                             84.1       7               9.0             15.9
# 9                             61.4      17              26.6             38.6
# 10                            88.0       3              10.3             12.0
# 11                            95.8       1               2.8              4.2
# 12                            78.3       4               9.1             17.4
# 13                            89.1       5               6.8             10.9
# 14                            95.8       0               0.0              0.0
# 15                            89.4       5               5.9             10.6
# 16                            82.9       6               8.6             17.1
# 17                            68.3      13              16.9             31.7
# 18                            83.7       7               9.0             16.3
# 19                            62.8      16              25.0             37.2
# 20                            45.9      20              36.4             54.1
# 21                         No Data       0               0.0          No Data
# 22                            85.2       4              11.1             14.8
# 23                            75.0       6              14.6             21.4
# 24                            87.5       6               8.8             12.5
# 25                            92.9       1               1.8              3.6
# 26                            87.7       7               8.5             12.3
# 27                            85.0       6               8.8             15.0
# 28                            58.8      21              27.3             41.2
# 29                            81.8       8              11.3             18.2
# 30                            85.2       4              11.1             14.8
# 31                            75.0       6              14.6             21.4
# 32                            87.5       6               8.8             12.5
# 33                            92.9       1               1.8              3.6
# 34                            89.1       6               7.3             10.9
# 35                            84.6       6               8.8             15.4
# 36                            58.8      21              27.3             41.2
# 37                            81.8       8              11.3             18.2
# 38                            60.9      18              27.3             39.1
# 39                            46.2      21              36.2             53.8
# 40                             0.0       3              60.0            100.0
# 41                            75.0       6              14.6             21.4
# 42                            85.7       7              10.3             14.3
# 43                            90.0       2               3.7              6.7
# 44                            86.9       8               9.8             13.1
# 45                            85.0       6               8.8             15.0
# 46                            58.5      22              28.6             41.5
# 47                            81.8       8              11.0             18.2
# 48                            61.7      18              27.7             38.3
# 49                            43.9      23              41.1             56.1
# 50                             0.0       3              60.0            100.0
# 51                               s       s                 s                s
# 52                               s       s                 s                s
# 53                            50.0       1              16.7             50.0
# 54                            33.3       2              14.3             66.7
# 55                               s       s                 s                s
# 56                               s       s                 s                s
# 57                            50.0       1              16.7             50.0
# 58                            33.3       2              14.3             66.7
# 59                               s       s                 s                s
# 60                               s       s                 s                s
# 61                               s       s                 s                s
# 62                               s       s                 s                s
# 63                               s       s                 s                s
# 64                            40.0       3              23.1             60.0
# 65                               s       s                 s                s
# 66                               s       s                 s                s
# 67                               s       s                 s                s
# 68                            33.3       2              14.3             66.7
# 69                               s       s                 s                s
# 70                               s       s                 s                s
# 71                               s       s                 s                s
# 72                               s       s                 s                s
# 73                               s       s                 s                s
# 74                               s       s                 s                s
# 75                               s       s                 s                s
# 76                               s       s                 s                s
# 77                               s       s                 s                s
# 78                            33.3       2              14.3             66.7
# 79                               s       s                 s                s
# 80                               s       s                 s                s
# 81                               s       s                 s                s
# 82                               s       s                 s                s
# 83                               s       s                 s                s
# 84                               s       s                 s                s
# 85                             0.0       3              50.0            100.0
# 86                               s       s                 s                s
# 87                               s       s                 s                s
# 88                               s       s                 s                s
# 89                            50.0       2              15.4             50.0
# 90                               s       s                 s                s
# 91                            83.3       1               6.7             16.7
# 92                               s       s                 s                s
# 93                               s       s                 s                s
# 94                               s       s                 s                s
# 95                               s       s                 s                s
# 96                               s       s                 s                s
# 97                            50.0       2              15.4             50.0
# 98                               s       s                 s                s
# 99                           100.0       0               0.0              0.0
#
#    Still Enrolled # Still Enrolled % of cohort Dropped Out #  \
# 0                 0                        0.0             1
# 1                 3                        8.3             7
# 2                10                       22.7            10
# 3                18                       24.7             7
# 4                18                       29.5            17
# 5                28                       32.9             8
# 6                18                       25.7            13
# 7                22                       28.6             5
# 8                15                       19.2            11
# 9                 8                       12.5             9
# 10                3                       10.3             1
# 11                4                       11.1             7
# 12               11                       25.0            10
# 13               18                       24.7             7
# 14               20                       32.8            17
# 15               30                       35.3             8
# 16               19                       27.1            13
# 17               25                       32.5             5
# 18               16                       20.5            11
# 19                9                       14.1             9
# 20               15                       27.3             3
# 21                4                       80.0             1
# 22                0                        0.0             8
# 23                1                        2.4            12
# 24                6                        8.8            14
# 25                7                       12.7            18
# 26               10                       12.2            15
# 27               13                       19.1            12
# 28                2                        2.6            16
# 29                0                        0.0            19
# 30                0                        0.0             8
# 31                1                        2.4            12
# 32                6                        8.8            14
# 33                7                       12.7            18
# 34               12                       14.6            15
# 35               14                       20.6            12
# 36                2                        2.6            16
# 37                0                        0.0            19
# 38                4                        6.1            11
# 39                4                        6.9            13
# 40                0                        0.0             2
# 41                1                        2.4            12
# 42                5                        7.4            14
# 43                2                        3.7            21
# 44                6                        7.3            15
# 45                7                       10.3            18
# 46                2                        2.6            14
# 47                1                        1.4            21
# 48                1                        1.5            11
# 49                2                        3.6            12
# 50                0                        0.0             2
# 51                s                          s             s
# 52                s                          s             s
# 53                2                       33.3             2
# 54                8                       57.1             2
# 55                s                          s             s
# 56                s                          s             s
# 57                2                       33.3             2
# 58                8                       57.1             2
# 59                s                          s             s
# 60                s                          s             s
# 61                s                          s             s
# 62                s                          s             s
# 63                s                          s             s
# 64                3                       23.1             5
# 65                s                          s             s
# 66                s                          s             s
# 67                s                          s             s
# 68                8                       57.1             2
# 69                s                          s             s
# 70                s                          s             s
# 71                s                          s             s
# 72                s                          s             s
# 73                s                          s             s
# 74                s                          s             s
# 75                s                          s             s
# 76                s                          s             s
# 77                s                          s             s
# 78                8                       57.1             2
# 79                s                          s             s
# 80                s                          s             s
# 81                s                          s             s
# 82                s                          s             s
# 83                s                          s             s
# 84                s                          s             s
# 85                3                       50.0             0
# 86                s                          s             s
# 87                s                          s             s
# 88                s                          s             s
# 89                4                       30.8             5
# 90                s                          s             s
# 91                5                       33.3             4
# 92                s                          s             s
# 93                s                          s             s
# 94                s                          s             s
# 95                s                          s             s
# 96                s                          s             s
# 97                4                       30.8             5
# 98                s                          s             s
# 99                6                       40.0             4
#
#    Dropped Out % of cohort
# 0                      3.4
# 1                     19.4
# 2                     22.7
# 3                      9.6
# 4                     27.9
# 5                      9.4
# 6                     18.6
# 7                      6.5
# 8                     14.1
# 9                     14.1
# 10                     3.4
# 11                    19.4
# 12                    22.7
# 13                     9.6
# 14                    27.9
# 15                     9.4
# 16                    18.6
# 17                     6.5
# 18                    14.1
# 19                    14.1
# 20                     5.5
# 21                    20.0
# 22                    22.2
# 23                    29.3
# 24                    20.6
# 25                    32.7
# 26                    18.3
# 27                    17.6
# 28                    20.8
# 29                    26.8
# 30                    22.2
# 31                    29.3
# 32                    20.6
# 33                    32.7
# 34                    18.3
# 35                    17.6
# 36                    20.8
# 37                    26.8
# 38                    16.7
# 39                    22.4
# 40                    40.0
# 41                    29.3
# 42                    20.6
# 43                    38.9
# 44                    18.3
# 45                    26.5
# 46                    18.2
# 47                    28.8
# 48                    16.9
# 49                    21.4
# 50                    40.0
# 51                       s
# 52                       s
# 53                    33.3
# 54                    14.3
# 55                       s
# 56                       s
# 57                    33.3
# 58                    14.3
# 59                       s
# 60                       s
# 61                       s
# 62                       s
# 63                       s
# 64                    38.5
# 65                       s
# 66                       s
# 67                       s
# 68                    14.3
# 69                       s
# 70                       s
# 71                       s
# 72                       s
# 73                       s
# 74                       s
# 75                       s
# 76                       s
# 77                       s
# 78                    14.3
# 79                       s
# 80                       s
# 81                       s
# 82                       s
# 83                       s
# 84                       s
# 85                     0.0
# 86                       s
# 87                       s
# 88                       s
# 89                    38.5
# 90                       s
# 91                    26.7
# 92                       s
# 93                       s
# 94                       s
# 95                       s
# 96                       s
# 97                    38.5
# 98                       s
# 99                    26.7
#
# [100 rows x 25 columns]

# %%
grad.shape
# Out:
# (508193, 25)

# %%
grad.isnull().values.any()
# Out:
# False

# %%
grad.dtypes
# Out:
# DBN                                 object
# School Name                         object
# Demographic Category                object
# Demographic Variable                object
# Cohort Year                         object
# Cohort                              object
# Total Cohort #                      object
# Total Grads #                       object
# Total Grads % of cohort             object
# Total Regents #                     object
# Total Regents % of cohort           object
# Total Regents % of grads            object
# Advanced Regents #                  object
# Advanced Regents % of cohort        object
# Advanced Regents % of grads         object
# Regents w/o Advanced #              object
# Regents w/o Advanced % of cohort    object
# Regents w/o Advanced % of grads     object
# Local #                             object
# Local % of cohort                   object
# Local % of grads                    object
# Still Enrolled #                    object
# Still Enrolled % of cohort          object
# Dropped Out #                       object
# Dropped Out % of cohort             object
# dtype: object

# %%
#Cleaning:  Checking data types and removialues, s  and extra commas
grad['Total Cohort #'] = grad['Total Cohort #'].astype(str)
grad['Total Grads % of cohort'] = grad['Total Grads % of cohort'].astype(str)
grad = grad.drop(grad[grad['Total Grads % of cohort'] == 's'].index)
grad = grad.drop(grad[grad['Total Cohort #'] == 's'].index)
grad['Cohort Year']= grad['Cohort Year'].str.replace(',','')
grad['Total Cohort #']= grad['Total Cohort #'].str.replace(',','')
grad.shape
# Out:
# (352392, 25)

# %%
# fixing data types
grad['Cohort'] = grad['Cohort'].astype(str)
grad['Demographic Variable'] = grad['Demographic Variable'].astype(str)
grad['Total Cohort #']= grad['Total Cohort #'].apply(pd.to_numeric)
grad['Total Grads % of cohort']= grad['Total Grads % of cohort'].apply(pd.to_numeric)
grad['Cohort Year']= grad['Cohort Year'].apply(pd.to_numeric)

grad.shape
# Out:
# (352392, 25)

# %%
null = grad.isnull().any(axis=1)
nullrows= grad[null]
nullrows
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Demographic Category, Demographic Variable, Cohort Year, Cohort, Total Cohort #, Total Grads #, Total Grads % of cohort, Total Regents #, Total Regents % of cohort, Total Regents % of grads, Advanced Regents #, Advanced Regents % of cohort, Advanced Regents % of grads, Regents w/o Advanced #, Regents w/o Advanced % of cohort, Regents w/o Advanced % of grads, Local #, Local % of cohort, Local % of grads, Still Enrolled #, Still Enrolled % of cohort, Dropped Out #, Dropped Out % of cohort]
# Index: []
#
# [0 rows x 25 columns]

# %%
grad.loc[grad['Total Grads % of cohort']== 's']
# Out:
# Empty DataFrame
# Columns: [DBN, School Name, Demographic Category, Demographic Variable, Cohort Year, Cohort, Total Cohort #, Total Grads #, Total Grads % of cohort, Total Regents #, Total Regents % of cohort, Total Regents % of grads, Advanced Regents #, Advanced Regents % of cohort, Advanced Regents % of grads, Regents w/o Advanced #, Regents w/o Advanced % of cohort, Regents w/o Advanced % of grads, Local #, Local % of cohort, Local % of grads, Still Enrolled #, Still Enrolled % of cohort, Dropped Out #, Dropped Out % of cohort]
# Index: []
#
# [0 rows x 25 columns]

# %%
grad.shape
# Out:
# (352392, 25)

# %%
grad.dtypes
# Out:
# DBN                                  object
# School Name                          object
# Demographic Category                 object
# Demographic Variable                 object
# Cohort Year                           int64
# Cohort                               object
# Total Cohort #                        int64
# Total Grads #                        object
# Total Grads % of cohort             float64
# Total Regents #                      object
# Total Regents % of cohort            object
# Total Regents % of grads             object
# Advanced Regents #                   object
# Advanced Regents % of cohort         object
# Advanced Regents % of grads          object
# Regents w/o Advanced #               object
# Regents w/o Advanced % of cohort     object
# Regents w/o Advanced % of grads      object
# Local #                              object
# Local % of cohort                    object
# Local % of grads                     object
# Still Enrolled #                     object
# Still Enrolled % of cohort           object
# Dropped Out #                        object
# Dropped Out % of cohort              object
# dtype: object

# %%
grad['Demographic Variable'].unique()
# Out:
# array(['All Students', 'Current ELL', 'ELL', 'Ever ELL', 'Former ELL',
#        'Never ELL', 'Not ELL', 'Asian', 'Black', 'Hispanic', 'Female',
#        'Male', 'Female Asian', 'Female Black', 'Female Hispanic',
#        'Male Asian', 'Male Black', 'Male Hispanic', 'Econ Disadv',
#        'Not Econ Disadv', 'Not SWD', 'SWD', 'Multi-Racial', 'White',
#        'Female Multi-Racial', 'Male White', 'Native American',
#        'Female Native American', 'Female White', 'Male Multi-Racial',
#        'Male Native American'], dtype=object)

# %%
#reduced rows to only SWD vs Not SWD
df = grad[grad['Demographic Variable'].str.contains('SWD')].copy()
df = df[['Cohort Year','Cohort','Demographic Variable','Total Grads % of cohort','Total Cohort #']].copy()
df["Class Size"] = df['Total Cohort #']

# %%
df['Cohort'].unique()
# Out:
# array(['4 year August', '4 year June', '5 year August', '5 year June',
#        '6 year June'], dtype=object)

# %%
#dropped to have just two categories 4 year and 6 year graduatipon rates
df = df.drop(df[df.Cohort.isin(['5 year June','4 year August','5 year August'])].index).copy()

# %%
# just used single school to see what data was appearing for each school
df.loc[grad['Cohort Year']== 2012].loc[grad['School Name']== 'ORCHARD COLLEGIATE ACADEMY']
# Out:
#       Cohort Year       Cohort Demographic Variable  Total Grads % of cohort  \
# 1064         2012  4 year June              Not SWD                     58.1
# 1094         2012  6 year June              Not SWD                     72.4
# 1116         2012  4 year June                  SWD                     38.5
# 1145         2012  6 year June                  SWD                     58.3
#
#       Total Cohort #  Class Size
# 1064              31          31
# 1094              29          29
# 1116              13          13
# 1145              12          12

# %%
# some decriptives looking ta mean size of cohorts and graduation rates for all years s
df.describe()
# Out:
#         Cohort Year  Total Grads % of cohort  Total Cohort #    Class Size
# count  16968.000000             16968.000000    16968.000000  16968.000000
# mean    2007.988685                59.731636      101.753182    101.753182
# std        3.618660                25.704943      166.271192    166.271192
# min     2001.000000                 0.000000        5.000000      5.000000
# 25%     2005.000000                41.400000       17.000000     17.000000
# 50%     2008.000000                62.900000       57.000000     57.000000
# 75%     2011.000000                80.300000       94.000000     94.000000
# max     2014.000000               100.000000     1348.000000   1348.000000

# %%
# looking at graduation rates rates and total size of cohort for all years both 4 year and 6 year graduation rate


Ch = df.groupby(['Cohort Year','Cohort','Demographic Variable'], as_index=False).agg({'Total Grads % of cohort':'mean','Class Size':'mean','Total Cohort #':'sum'})
Ch
# Out:
#     Cohort Year       Cohort Demographic Variable  Total Grads % of cohort  \
# 0          2001  4 year June              Not SWD                54.016129
# 1          2001  4 year June                  SWD                26.367816
# 2          2001  6 year June              Not SWD                70.058065
# 3          2001  6 year June                  SWD                34.497701
# 4          2002  4 year June              Not SWD                55.383902
# 5          2002  4 year June                  SWD                27.950549
# 6          2002  6 year June              Not SWD                70.648780
# 7          2002  6 year June                  SWD                40.362637
# 8          2003  4 year June              Not SWD                58.665417
# 9          2003  4 year June                  SWD                28.225806
# 10         2003  6 year June              Not SWD                73.551477
# 11         2003  6 year June                  SWD                44.350000
# 12         2004  4 year June              Not SWD                61.679924
# 13         2004  4 year June                  SWD                34.362745
# 14         2004  6 year June              Not SWD                75.384015
# 15         2004  6 year June                  SWD                49.552941
# 16         2005  4 year June              Not SWD                64.662866
# 17         2005  4 year June                  SWD                36.182230
# 18         2005  6 year June              Not SWD                77.228155
# 19         2005  6 year June                  SWD                51.079514
# 20         2006  4 year June              Not SWD                65.822189
# 21         2006  4 year June                  SWD                39.063636
# 22         2006  6 year June              Not SWD                77.796000
# 23         2006  6 year June                  SWD                51.569909
# 24         2007  4 year June              Not SWD                63.045378
# 25         2007  4 year June                  SWD                37.153869
# 26         2007  6 year June              Not SWD                77.204494
# 27         2007  6 year June                  SWD                52.623964
# 28         2008  4 year June              Not SWD                62.680376
# 29         2008  4 year June                  SWD                39.238202
# 30         2008  6 year June              Not SWD                77.017473
# 31         2008  6 year June                  SWD                56.626629
# 32         2009  4 year June              Not SWD                60.611628
# 33         2009  4 year June                  SWD                40.544414
# 34         2009  6 year June              Not SWD                75.972610
# 35         2009  6 year June                  SWD                58.476486
# 36         2010  4 year June              Not SWD                64.722276
# 37         2010  4 year June                  SWD                46.346970
# 38         2010  6 year June              Not SWD                79.069734
# 39         2010  6 year June                  SWD                63.741919
# 40         2011  4 year June              Not SWD                67.633415
# 41         2011  4 year June                  SWD                46.305263
# 42         2011  6 year June              Not SWD                80.206634
# 43         2011  6 year June                  SWD                62.304511
# 44         2012  4 year June              Not SWD                71.160187
# 45         2012  4 year June                  SWD                52.297596
# 46         2012  6 year June              Not SWD                82.035981
# 47         2012  6 year June                  SWD                68.351202
# 48         2013  4 year June              Not SWD                72.634943
# 49         2013  4 year June                  SWD                52.332944
# 50         2014  4 year June              Not SWD                73.863303
# 51         2014  4 year June                  SWD                57.926573
#
#     Class Size  Total Cohort #
# 0   272.661290           50715
# 1    40.994253            7133
# 2   272.661290           50715
# 3    40.994253            7133
# 4   268.068293           54954
# 5    28.098901            5114
# 6   268.068293           54954
# 7    28.098901            5114
# 8   225.995833           54239
# 9    31.516129            6839
# 10  230.438819           54614
# 11   30.864486            6605
# 12  210.734848           55634
# 13   30.450980            7765
# 14  211.959108           57017
# 15   28.937255            7379
# 16  190.615635           58519
# 17   28.679443            8231
# 18  192.226537           59398
# 19   27.565972            7939
# 20  178.363905           60287
# 21   27.354232            8726
# 22  177.380000           62083
# 23   27.519757            9054
# 24  173.627451           61985
# 25   27.178571            9132
# 26  173.699438           61837
# 27   26.059172            8808
# 28  164.357527           61141
# 29   26.272472            9353
# 30  164.768817           61294
# 31   24.101983            8508
# 32  162.095607           62731
# 33   24.520436            8999
# 34  158.640827           61394
# 35   24.308108            8994
# 36  143.573850           59296
# 37   25.045455            9918
# 38  142.975787           59049
# 39   24.712121            9786
# 40  138.643735           56428
# 41   25.619048           10222
# 42  138.326781           56299
# 43   25.283208           10088
# 44  135.168618           57717
# 45   25.459135           10591
# 46  134.591121           57605
# 47   24.891827           10355
# 48  129.402299           56290
# 49   25.009346           10704
# 50  130.201835           56768
# 51   25.862471           11095

# %%
#plot to see changes over time in graduation rates for student with and without diabilies

b = sns.lineplot(data=Ch, x="Cohort Year", y="Total Grads % of cohort", hue="Demographic Variable", style="Cohort")
b.set_title('4 Year and 6 year Graduation Rates')
# Out:
# Text(0.5, 1.0, '4 Year and 6 year Graduation Rates')

# %%
dfresults = df.groupby(['Cohort','Demographic Variable']).agg({'Total Grads % of cohort':'mean','Total Cohort #':'sum', 'Class Size':'mean'})
dfresults
# Out:
#                                   Total Grads % of cohort  Total Cohort #  \
# Cohort      Demographic Variable
# 4 year June Not SWD                             65.267574          806704
#             SWD                                 42.660469          123822
# 6 year June Not SWD                             77.127813          696259
#             SWD                                 55.223667           99763
#
#                                   Class Size
# Cohort      Demographic Variable
# 4 year June Not SWD               168.978634
#             SWD                    27.147994
# 6 year June Not SWD               177.662414
#             SWD                    26.861335

# %%
Final = df.drop(df[df.Cohort.isin(['4 year June'])].index)
Final = Final.groupby(['Demographic Variable','Cohort Year'],as_index= False).agg({'Total Grads % of cohort':'mean','Total Cohort #':'sum','Class Size':'mean'})

Final
# Out:
#    Demographic Variable  Cohort Year  Total Grads % of cohort  Total Cohort #  \
# 0               Not SWD         2001                70.058065           50715
# 1               Not SWD         2002                70.648780           54954
# 2               Not SWD         2003                73.551477           54614
# 3               Not SWD         2004                75.384015           57017
# 4               Not SWD         2005                77.228155           59398
# 5               Not SWD         2006                77.796000           62083
# 6               Not SWD         2007                77.204494           61837
# 7               Not SWD         2008                77.017473           61294
# 8               Not SWD         2009                75.972610           61394
# 9               Not SWD         2010                79.069734           59049
# 10              Not SWD         2011                80.206634           56299
# 11              Not SWD         2012                82.035981           57605
# 12                  SWD         2001                34.497701            7133
# 13                  SWD         2002                40.362637            5114
# 14                  SWD         2003                44.350000            6605
# 15                  SWD         2004                49.552941            7379
# 16                  SWD         2005                51.079514            7939
# 17                  SWD         2006                51.569909            9054
# 18                  SWD         2007                52.623964            8808
# 19                  SWD         2008                56.626629            8508
# 20                  SWD         2009                58.476486            8994
# 21                  SWD         2010                63.741919            9786
# 22                  SWD         2011                62.304511           10088
# 23                  SWD         2012                68.351202           10355
#
#     Class Size
# 0   272.661290
# 1   268.068293
# 2   230.438819
# 3   211.959108
# 4   192.226537
# 5   177.380000
# 6   173.699438
# 7   164.768817
# 8   158.640827
# 9   142.975787
# 10  138.326781
# 11  134.591121
# 12   40.994253
# 13   28.098901
# 14   30.864486
# 15   28.937255
# 16   27.565972
# 17   27.519757
# 18   26.059172
# 19   24.101983
# 20   24.308108
# 21   24.712121
# 22   25.283208
# 23   24.891827

# %%
Size = sns.lineplot(data=Final, x="Cohort Year", y="Total Cohort #", hue = "Demographic Variable")
Size.set_title('Cohort Size')

plt.legend(title='Disability Status')
plt.show(Size)

# %%
cl= sns.lineplot(data=Final, x="Cohort Year", y="Class Size", hue = "Demographic Variable")
cl.set_title('Class Size')
cl.set(ylabel = "Mean # in Class")
plt.legend(title='Disability Status')
plt.show(cl)

# %%
#creating data frame to compare first year with final year 6 year graduation rate
# changed year to categorical so I could make a bar chart
dfc = df.copy()
dfc['Cohort Year']= df['Cohort Year'].apply(str)
dfc = dfc[dfc['Cohort'].str.contains('6 year June')]
# selecting years of interest
values=["2012","2001"]
dfc = (dfc[dfc["Cohort Year"].isin(values)] )
dfc.head(25)
# Out:
#      Cohort Year       Cohort Demographic Variable  Total Grads % of cohort  \
# 1094        2012  6 year June              Not SWD                     72.4
# 1145        2012  6 year June                  SWD                     58.3
# 2434        2012  6 year June              Not SWD                     83.3
# 2445        2001  6 year June              Not SWD                     87.7
# 2491        2012  6 year June                  SWD                     62.5
# 2502        2001  6 year June                  SWD                     57.1
# 3762        2012  6 year June              Not SWD                     94.0
# 3773        2001  6 year June              Not SWD                     77.6
# 3819        2012  6 year June                  SWD                     86.4
# 3830        2001  6 year June                  SWD                     66.7
# 4665        2012  6 year June              Not SWD                     50.7
# 4705        2012  6 year June                  SWD                     66.7
# 5877        2012  6 year June              Not SWD                     88.9
# 5888        2001  6 year June              Not SWD                     76.8
# 5935        2012  6 year June                  SWD                     38.5
# 5946        2001  6 year June                  SWD                     30.8
# 7218        2012  6 year June              Not SWD                     47.1
# 7274        2012  6 year June                  SWD                     42.9
# 8502        2012  6 year June              Not SWD                    100.0
# 8513        2001  6 year June              Not SWD                     94.1
# 8553        2012  6 year June                  SWD                    100.0
# 9842        2012  6 year June              Not SWD                     66.4
# 9853        2001  6 year June              Not SWD                     54.3
# 9899        2012  6 year June                  SWD                     44.4
# 9910        2001  6 year June                  SWD                     40.0
#
#       Total Cohort #  Class Size
# 1094              29          29
# 1145              12          12
# 2434              48          48
# 2445              57          57
# 2491              16          16
# 2502               7           7
# 3762              67          67
# 3773              49          49
# 3819              22          22
# 3830              12          12
# 4665              73          73
# 4705              15          15
# 5877              54          54
# 5888              56          56
# 5935              13          13
# 5946              13          13
# 7218             242         242
# 7274              14          14
# 8502             179         179
# 8513              17          17
# 8553               7           7
# 9842             116         116
# 9853              81          81
# 9899               9           9
# 9910               5           5

# %%
dfc.dtypes
# Out:
# Cohort Year                 object
# Cohort                      object
# Demographic Variable        object
# Total Grads % of cohort    float64
# Total Cohort #               int64
# Class Size                   int64
# dtype: object

# %%
#Results C omparing 2012 and 2021 6 year graduation Rate
Results02_12 = dfc.groupby(['Cohort Year','Demographic Variable'], as_index=  False).agg({'Total Cohort #':'sum','Total Grads % of cohort':'mean', 'Class Size': 'mean'})
Results02_12
# Out:
#   Cohort Year Demographic Variable  Total Cohort #  Total Grads % of cohort  \
# 0        2001              Not SWD           50715                70.058065
# 1        2001                  SWD            7133                34.497701
# 2        2012              Not SWD           57605                82.035981
# 3        2012                  SWD           10355                68.351202
#
#    Class Size
# 0  272.661290
# 1   40.994253
# 2  134.591121
# 3   24.891827

# %%
#Plot Size of Cohort- In separate subplot
R = Results02_12.rename(columns={'Demographic Variable': 'Disability Status'})

CP = sns.catplot(R, kind="bar",x="Cohort Year", y="Total Cohort #", col="Disability Status",  aspect= .7)


CP.set_titles("{col_name}")
CP.fig.suptitle("Cohort Size", y=1.05)

for CP in CP.axes.ravel():
  for c in CP.containers:
    CP.bar_label(c)

# %%
R.shape
# Out:
# (4, 5)

# %%
(#Plot Graduation 2001 abd 2012
pc = sns.catplot(R, kind="bar",x="Cohort Year", y="Total Grads % of cohort", col="Disability Status", aspect= .7)
pc.fig.suptitle("Graduation Rate No Disability vs SWD ", y=1.05)
for pc in pc.axes.ravel():
  for c in pc.containers:
    pc.bar_label(c)

# %%
# Analyses to see if diability status and year predicted graduation rate and cohort sizes
import statsmodels.api as sm
from statsmodels.formula.api import ols
center_function = lambda x: x - x.mean()
centered = df[['Cohort Year','Cohort','Demographic Variable','Total Grads % of cohort','Total Cohort #']].copy()
centered['Cohort Year'] = center_function(Final['Cohort Year'])

data = pd.DataFrame({ 'x': centered['Demographic Variable'], 'y': centered['Total Grads % of cohort'], 'z':centered['Cohort Year'], 'f':centered['Total Cohort #']}).copy()

model = ols("y ~ x*z", data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     1766.
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):               0.00
# Time:                        06:27:27   Log-Likelihood:                -76860.
# No. Observations:               16968   AIC:                         1.537e+05
# Df Residuals:                   16964   BIC:                         1.538e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     70.6474      0.241    293.503      0.000      70.176      71.119
# x[T.SWD]     -22.4347      0.345    -65.088      0.000     -23.110     -21.759
# z              0.8404      0.066     12.649      0.000       0.710       0.971
# x[T.SWD]:z     1.2584      0.095     13.211      0.000       1.072       1.445
# ==============================================================================
# Omnibus:                      365.688   Durbin-Watson:                   0.578
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              391.290
# Skew:                          -0.357   Prob(JB):                     1.08e-85
# Kurtosis:                       3.206   Cond. No.                         9.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Conclusion: Graduation rates for SWD are lower than for students without disabilities. The graduation rates have increased for both groups of studnets. The graduation rate icreased conitinously for SWD but appears to have leveled off for non diabled students. This is especially evident in the 6 year graduation rates.
#
# The number of students in each school's cohort has decreased  but the ovarall number of students in  NYC  has increased due to the opening of new schools.
